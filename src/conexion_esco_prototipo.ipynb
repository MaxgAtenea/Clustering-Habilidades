# %%
import requests

# %%
uri = "http://data.europa.eu/esco/skill/cd56a093-3400-4635-80bd-b9611dcf1542"
# Endpoint de ESCO (modifica a 'concept' si es necesario)
url = "https://ec.europa.eu/esco/api/resource/skill"

params = {
"uri": uri,
"language": "es"
}

headers = {
"Accept": "application/json"
}

response = requests.get(url, params=params, headers=headers)
data = response.json()

# %%
data
# Out:
# {'className': 'Skill',
#  'classId': 'http://data.europa.eu/esco/model#Skill',
#  'uri': 'http://data.europa.eu/esco/skill/cd56a093-3400-4635-80bd-b9611dcf1542',
#  'title': 'Gamemaker Studio',
#  'referenceLanguage': ['en'],
#  'preferredLabel': {'de': 'Gamemaker Studio',
#   'no': 'Gamemaker Studio',
#   'fi': 'Gamemaker Studio',
#   'en-us': 'Gamemaker Studio',
#   'pt': 'Gamemaker Studio',
#   'bg': 'Gamemaker Studio',
#   'lt': '„Gamemaker Studio“',
#   'lv': 'Gamemaker Studio',
#   'hr': 'Gamemaker Studio',
#   'fr': 'Gamemaker Studio',
#   'hu': 'Gamemaker Studio',
#   'sk': 'Gamemaker Studio',
#   'sl': 'Gamemaker Studio',
#   'ga': 'Gamemaker Studio',
#   'sv': 'Gamemaker Studio',
#   'el': 'Gamemaker Studio',
#   'mt': 'Gamemaker Studio',
#   'en': 'Gamemaker Studio',
#   'is': 'Gamemaker Studio',
#   'it': 'Gamemaker Studio',
#   'es': 'Gamemaker Studio',
#   'et': 'Gamemaker Studio',
#   'cs': 'Gamemaker Studio',
#   'ar': 'Gamemaker Studio',
#   'pl': 'Gamemaker Studio',
#   'ro': 'Gamemaker Studio',
#   'da': 'Gamemaker Studio',
#   'nl': 'Gamemaker Studio'},
#  'description': {'no': {'literal': 'Den plattformdekkende spillplattformen som er skrevet på programmeringsspråket Delphi og består av integrerte utviklingsmiljøer og spesialiserte designverktøy, designet for rask iterasjon av brukerderiverte dataspill.',
#    'mimetype': 'plain/text'},
#   'de': {'literal': 'Die plattformübergreifende Spiel-Engine ist in der Programmiersprache Delphi geschrieben und besteht aus integrierten Entwicklungsumgebungen und speziellen Designwerkzeugen, die für die schnelle Iteration von Computerspielen der Nutzer konzipiert wurden.',
#    'mimetype': 'plain/text'},
#   'fi': {'literal': 'Delphi-ohjelmointikielellä toimiva alustariippumaton pelimoottori, joka koostuu integroiduista kehitysympäristöistä ja erikoissuunnitteluvälineistä. Suunniteltu tietokonepelien nopeaan suunnitteluun käyttäjälähtöisesti.',
#    'mimetype': 'plain/text'},
#   'en-us': {'literal': 'The cross-platform game engine which is written in Delphi programming language and consists of integrated development environments and specialized design tools, designed for the rapid iteration of user-derived computer games.',
#    'mimetype': 'plain/text'},
#   'pt': {'literal': 'O motor de jogos de plataformas cruzadas que está escrito na linguagem de programação Delphi e consiste em ambientes de desenvolvimento integrado e ferramentas especializadas de conceção, concebidos para a rápida iteração de jogos de computador derivados do utilizador.',
#    'mimetype': 'plain/text'},
#   'bg': {'literal': 'Игрален софтуер с кръстосана платформа, който е написан на програмния език Delphi и който се състои от интегрирани среди за разработка и специализирани инструменти за проектиране, създадени за бързо повторение на потребителски компютърни игри.',
#    'mimetype': 'plain/text'},
#   'lt': {'literal': '„Delphi“ programavimo kalba parengtas įvairių platformų žaidimo variklis, kurį sudaro integruota kūrimo aplinka ir specializuotos projektavimo priemonės, skirtos greitam naudotojų sukurtų kompiuterinių žaidimų atkartojimui.',
#    'mimetype': 'plain/text'},
#   'hr': {'literal': 'Međuplatformska jezgra igre koja je napisana programskim jezikom Delphi, a sastoji se od integriranog razvojnog okruženja i specijaliziranih alata za projektiranje, namijenjenih za brzu iteraciju računalnih igara koje prenose korisnici.',
#    'mimetype': 'plain/text'},
#   'lv': {'literal': 'Starpplatformu spēļu dzinis, kas ir izstrādāts programmēšanas valodā “Delphi” un kas sastāv no integrētas programmēšanas vides un specializētiem dizaina rīkiem, kas paredzēti lietotāju atvasinātu datorspēļu ātrai iterācijai.',
#    'mimetype': 'plain/text'},
#   'fr': {'literal': 'Le moteur de jeu multiplateforme, qui est rédigé dans la langue de programmation Delphi et qui se compose d’environnements de développement et d’outils de conception spécialisés conçus pour l’itération rapide de jeux informatiques issus de l’utilisateur.',
#    'mimetype': 'plain/text'},
#   'hu': {'literal': 'Delphi programozási nyelven íródott, platformon belüli játékmotor, amely integrált fejlesztési környezetekből és specializált tervezési eszközökből áll, és a felhasználó által létrehozott számítógépes játékok gyors iterációját szolgálja.',
#    'mimetype': 'plain/text'},
#   'sk': {'literal': 'Herný stroj pre viaceré platformy, ktorý je napísaný v programovacom jazyku Delphi a ktorý pozostáva z integrovaného vývojového prostredia a špecializovaných nástrojov dizajnu navrhnutých na rýchlu iteráciu počítačových hier odvodených od používateľa.',
#    'mimetype': 'plain/text'},
#   'sl': {'literal': 'Medplatformni igralni pogon, napisan v programskem jeziku Delphi, sestavljen iz integriranih razvojnih okolij in oblikovalskih orodij, zasnovanih za hitro ustvarjanje uporabniških računalniških igric.',
#    'mimetype': 'plain/text'},
#   'ga': {'literal': 'An t-inneall cluiche trasardáin atá scríofa i dteanga ríomhchláraithe Delphi agus lena gcuimsítear timpeallachtaí forbartha comhtháite agus sain-uirlisí deartha, arna ndearadh chun cluichí ríomhaireachta atá díorthaithe ag úsáideoirí a atriail go tapa.',
#    'mimetype': 'plain/text'},
#   'sv': {'literal': 'Spelmotorn för flera plattformar som skrivs i programmeringsspråket Delphi och består av integrerade utvecklingsmiljöer och specialiserade designverktyg, vilka utformats för snabb iteration av användarhärledda dataspel.',
#    'mimetype': 'plain/text'},
#   'mt': {'literal': 'Il-magna tal-logħob implimentata fuq ħafna pjattaformi li hija miktuba bil-lingwa tal-iprogrammar Delphi u li tikkonsisti minn ambjenti ta’ żvilupp integrat u għodod ta’ disinn speċjalizzati, iddisinjati għall-iterazzjoni rapida ta’ logħob tal-kompjuter li jkun ġej mill-utenti.',
#    'mimetype': 'plain/text'},
#   'el': {'literal': 'Παιχνιδομηχανή πολλαπλών πλατφορμών με κώδικα σε γλώσσα προγραμματισμού της Delphi, που αποτελείται από ολοκληρωμένα περιβάλλοντα ανάπτυξης και εξειδικευμένα εργαλεία σχεδιασμού, και έχει σχεδιαστεί για την ταχεία επανάληψη των ηλεκτρονικών παιχνιδιών που προέρχονται από χρήστες.',
#    'mimetype': 'plain/text'},
#   'en': {'literal': 'The cross-platform game engine which is written in Delphi programming language and consists of integrated development environments and specialised design tools, designed for the rapid iteration of user-derived computer games.',
#    'mimetype': 'plain/text'},
#   'is': {'literal': 'Leikjavél sem er skrifuð með Delphi hugbúnaðinum og samanstendur af samþættu þróunarumhverfi og sérhæfðum hönnunartækjum sem er hönnuð fyrir hraða endurtekningu á tölvuleiki sem gerðar eru fyrir neytendur.',
#    'mimetype': 'plain/text'},
#   'it': {'literal': 'Motore per videogiochi multi-piattaforma, scritto nel linguaggio di programmazione Delphi, che consiste di ambienti di sviluppo integrati e strumenti di progettazione specializzati, concepiti per l’iterazione rapida di giochi informatici derivati dagli utenti.',
#    'mimetype': 'plain/text'},
#   'es': {'literal': 'Motor de juego de plataforma transversal que está redactado en un lenguaje de programación Delphi y que consiste en entornos de desarrollo integrados y herramientas de diseño especializadas diseñadas para la iteración rápida de juegos informáticos creados por usuarios.',
#    'mimetype': 'plain/text'},
#   'et': {'literal': 'Programmeerimiskeeles Delphi kirjutatud platvormiülene mängumootor, mis koosneb integreeritud arenduskeskkondadest ja eriprojekteerimisvahenditest, et kiiresti itereerida kasutaja loodud arvutimänge.',
#    'mimetype': 'plain/text'},
#   'cs': {'literal': 'Víceplatformový herní engine naprogramovaný v\xa0jazyce Delphi, který\xa0se skládá z\xa0integrovaných vývojových prostředí a\xa0specializovaných vývojových nástrojů k\xa0rychlé iteraci počítačových her ze strany uživatelů.',
#    'mimetype': 'plain/text'},
#   'ar': {'literal': 'محرك ألعاب متعدد المنصات مكتوبًا بلغة البرمجة "Delphi" يتألف من بيئات التطوير المتكامل وأدوات التصميم المتخصصة، للتكرار السريع لألعاب الكمبيوتر المستمدة من المستخدم.',
#    'mimetype': 'plain/text'},
#   'pl': {'literal': 'Wieloplatformowy silnik gry napisany w języku programowania Delphi, składający się ze zintegrowanego środowiska programistycznego i specjalistycznych narzędzi projektowania przeznaczony do szybkich iteracji gier komputerowych tworzonych przez użytkownika.',
#    'mimetype': 'plain/text'},
#   'ro': {'literal': 'Motorul de jocuri cu platforme încrucișate care este scris în limbajul de programare Delphi și constă în medii de dezvoltare integrate și instrumente de proiectare specializate concepute pentru iterația rapidă a jocurilor pe calculator generate de utilizatori.',
#    'mimetype': 'plain/text'},
#   'da': {'literal': 'En tværgående spillemotor, der er udviklet i Delphi-programmeringssproget, og som består af integrerede udviklingsmiljøer og specialiserede designværktøjer, der er konstrueret til hurtig udbredelse af brugerbaserede computerspil.',
#    'mimetype': 'plain/text'},
#   'nl': {'literal': 'De cross-platform game engin die geschreven is in de programmeertaal Delphi en bestaat uit een geïntegreerde ontwikkelingsomgeving en gespecialiseerde ontwerptools, bedoeld voor de snelle iteratie van door de gebruiker gegenereerde computerspellen.',
#    'mimetype': 'plain/text'}},
#  'status': 'released',
#  '_links': {'self': {'href': 'https://ec.europa.eu/esco/api/resource/skill?uri=http://data.europa.eu/esco/skill/cd56a093-3400-4635-80bd-b9611dcf1542&language=es',
#    'uri': 'http://data.europa.eu/esco/skill/cd56a093-3400-4635-80bd-b9611dcf1542',
#    'title': 'Gamemaker Studio'},
#   'isInScheme': [{'href': 'https://ec.europa.eu/esco/api/resource/taxonomy?uri=http://data.europa.eu/esco/concept-scheme/skills&language=es',
#     'uri': 'http://data.europa.eu/esco/concept-scheme/skills',
#     'title': 'Competencias ESCO'},
#    {'href': 'https://ec.europa.eu/esco/api/resource/taxonomy?uri=http://data.europa.eu/esco/concept-scheme/member-skills&language=es',
#     'uri': 'http://data.europa.eu/esco/concept-scheme/member-skills',
#     'title': 'Capacidades individuales ESCO'}],
#   'hasSkillType': [{'href': 'https://ec.europa.eu/esco/api/resource/concept?uri=http://data.europa.eu/esco/skill-type/knowledge&language=es',
#     'uri': 'http://data.europa.eu/esco/skill-type/knowledge',
#     'title': 'conocimiento'}],
#   'hasReuseLevel': [{'href': 'https://ec.europa.eu/esco/api/resource/concept?uri=http://data.europa.eu/esco/skill-reuse-level/sector-specific&language=es',
#     'uri': 'http://data.europa.eu/esco/skill-reuse-level/sector-specific',
#     'title': 'Capacidades y competencias específicas del sector',
#     'code': 'Level 3'}],
#   'broaderHierarchyConcept': [{'href': 'https://ec.europa.eu/esco/api/resource/concept?uri=http://data.europa.eu/esco/isced-f/0211&language=es',
#     'uri': 'http://data.europa.eu/esco/isced-f/0211',
#     'title': 'técnicas audiovisuales y producción para medios de comunicación'}],
#   'broaderSkill': [{'href': 'https://ec.europa.eu/esco/api/resource/skill?uri=http://data.europa.eu/esco/skill/966f2fd3-3de6-42da-b87c-da924c6d7960&language=es',
#     'uri': 'http://data.europa.eu/esco/skill/966f2fd3-3de6-42da-b87c-da924c6d7960',
#     'title': 'sistemas de creación de juegos digitales',
#     'skillType': 'http://data.europa.eu/esco/skill-type/knowledge'}]},
#  '_embedded': {'ancestors': [{'title': 'Gamemaker Studio',
#     '_links': {'self': {'href': 'https://ec.europa.eu/esco/api/resource/skill?uri=http://data.europa.eu/esco/skill/cd56a093-3400-4635-80bd-b9611dcf1542&language=es',
#       'uri': 'http://data.europa.eu/esco/skill/cd56a093-3400-4635-80bd-b9611dcf1542'}},
#     'parents': ['http://data.europa.eu/esco/skill/966f2fd3-3de6-42da-b87c-da924c6d7960',
#      'http://data.europa.eu/esco/isced-f/0211']},
#    {'title': 'técnicas audiovisuales y producción para medios de comunicación',
#     '_links': {'self': {'href': 'https://ec.europa.eu/esco/api/resource/skill?uri=http://data.europa.eu/esco/isced-f/0211&language=es',
#       'uri': 'http://data.europa.eu/esco/isced-f/0211'}},
#     'parents': ['http://data.europa.eu/esco/isced-f/021']},
#    {'title': 'artes',
#     '_links': {'self': {'href': 'https://ec.europa.eu/esco/api/resource/skill?uri=http://data.europa.eu/esco/isced-f/021&language=es',
#       'uri': 'http://data.europa.eu/esco/isced-f/021'}},
#     'parents': ['http://data.europa.eu/esco/isced-f/02']},
#    {'title': 'artes y humanidades',
#     '_links': {'self': {'href': 'https://ec.europa.eu/esco/api/resource/skill?uri=http://data.europa.eu/esco/isced-f/02&language=es',
#       'uri': 'http://data.europa.eu/esco/isced-f/02'}},
#     'parents': ['http://data.europa.eu/esco/skill/K']},
#    {'title': 'conocimientos',
#     '_links': {'self': {'href': 'https://ec.europa.eu/esco/api/resource/skill?uri=http://data.europa.eu/esco/skill/K&language=es',
#       'uri': 'http://data.europa.eu/esco/skill/K'}},
#     'parents': []},
#    {'title': 'sistemas de creación de juegos digitales',
#     '_links': {'self': {'href': 'https://ec.europa.eu/esco/api/resource/skill?uri=http://data.europa.eu/esco/skill/966f2fd3-3de6-42da-b87c-da924c6d7960&language=es',
#       'uri': 'http://data.europa.eu/esco/skill/966f2fd3-3de6-42da-b87c-da924c6d7960'}},
#     'parents': ['http://data.europa.eu/esco/isced-f/0211']}]}}
